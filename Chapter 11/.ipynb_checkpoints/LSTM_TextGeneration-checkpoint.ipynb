# %%
import re
import numpy as np
from keras.utils import np_utils
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Dense, Dropout, LSTM

import keras.backend as K
from IPython.display import display
from IPython.display import HTML as html_print
# Out:
# Using TensorFlow backend.
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/chandru4ni/python-environments/qc/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Read data from the corpus file, galaxy.txt
fname = "galaxy.txt"
rtext = open(fname, 'r', encoding='utf-8').read()
rtext = re.sub(r'[ ]+', ' ', rtext)

# generate a mapping of characters which are unique  and map them to integers
characters = sorted(list(set(rtext)))
print (len(characters))
charactersToInteger = dict((ch, i) for i, ch in enumerate(characters))
integerToCharacter = dict((index, ch) for index, ch in enumerate(characters))

# Get the count of characters and unique characters
numOfChars = len(rtext)
numOfVocab = len(characters)

# To get the the dataset for training, prepare input to output pairs encoded as integers
lengthOfSequence = 100
dataX = []
dataY = []
# Out:
# 77

# %%
# dataX will be input data and dataX will be the target output
for i in range(0, numOfChars - lengthOfSequence, 1):
    inSequence = rtext[i:i + lengthOfSequence]
    outSequence = rtext[i + lengthOfSequence]
    dataX.append([charactersToInteger[char] for char in inSequence])
    dataY.append(charactersToInteger[outSequence])

numOfPatterns = len(dataX)
print("Total number of Patterns in the corpus or dataset: ", numOfPatterns)

# reshape X 
# [samples, time steps, features]
X = np.reshape(dataX, (numOfPatterns, lengthOfSequence, 1))

# normalize X for training
X = X / float(numOfVocab)

# one hot encode the output variable which will be the target output
y = np_utils.to_categorical(dataY)
# Out:
# Total number of Patterns in the corpus or dataset:  10381

# %%
# The file name that needs to be used to save the model
filepath="galaxyLSTMmodel-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# Now define the LSTM model with required layers
model = Sequential()

model.add(LSTM(64, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.6))

model.add(LSTM(77))
model.add(Dropout(0.5))

# define loss function and epochs for the training
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary

# Train model with same data
model.fit(X, y, epochs=200, batch_size=1024, callbacks=callbacks_list)

# LSTM layer with output shape (Batch_Size, 512)
lstm = model.layers[2]
# Out:
# Epoch 1/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 12.4502 - acc: 0.0071
#
# Epoch 00001: loss improved from inf to 12.45016, saving model to galaxyLSTMmodel-01-12.4502.hdf5
# Epoch 2/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 11.8684 - acc: 0.0339
#
# Epoch 00002: loss improved from 12.45016 to 11.86837, saving model to galaxyLSTMmodel-02-11.8684.hdf5
# Epoch 3/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 13.0638 - acc: 0.0476
#
# Epoch 00003: loss did not improve from 11.86837
# Epoch 4/200
# 10381/10381 [==============================] - 12s 1ms/step - loss: 12.2442 - acc: 0.0497
#
# Epoch 00004: loss did not improve from 11.86837
# Epoch 5/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 12.0702 - acc: 0.0516
#
# Epoch 00005: loss did not improve from 11.86837
# Epoch 6/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 11.9824 - acc: 0.0527
#
# Epoch 00006: loss did not improve from 11.86837
# Epoch 7/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 11.9221 - acc: 0.0518
#
# Epoch 00007: loss did not improve from 11.86837
# Epoch 8/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 12.1178 - acc: 0.0496
#
# Epoch 00008: loss did not improve from 11.86837
# Epoch 9/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.9729 - acc: 0.0533
#
# Epoch 00009: loss did not improve from 11.86837
# Epoch 10/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 12.0482 - acc: 0.0532
#
# Epoch 00010: loss did not improve from 11.86837
# Epoch 11/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8607 - acc: 0.0530
#
# Epoch 00011: loss improved from 11.86837 to 11.86067, saving model to galaxyLSTMmodel-11-11.8607.hdf5
# Epoch 12/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8612 - acc: 0.0522
#
# Epoch 00012: loss did not improve from 11.86067
# Epoch 13/200
# 10381/10381 [==============================] - 20s 2ms/step - loss: 11.8475 - acc: 0.0567
#
# Epoch 00013: loss improved from 11.86067 to 11.84748, saving model to galaxyLSTMmodel-13-11.8475.hdf5
# Epoch 14/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.9731 - acc: 0.0582
#
# Epoch 00014: loss did not improve from 11.84748
# Epoch 15/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.7302 - acc: 0.0584
#
# Epoch 00015: loss improved from 11.84748 to 11.73025, saving model to galaxyLSTMmodel-15-11.7302.hdf5
# Epoch 16/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.8570 - acc: 0.0590
#
# Epoch 00016: loss did not improve from 11.73025
# Epoch 17/200
# 10381/10381 [==============================] - 16s 1ms/step - loss: 11.9575 - acc: 0.0559
#
# Epoch 00017: loss did not improve from 11.73025
# Epoch 18/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 11.9367 - acc: 0.0524
#
# Epoch 00018: loss did not improve from 11.73025
# Epoch 19/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 11.7394 - acc: 0.0533
#
# Epoch 00019: loss did not improve from 11.73025
# Epoch 20/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 12.0783 - acc: 0.0551
#
# Epoch 00020: loss did not improve from 11.73025
# Epoch 21/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.7761 - acc: 0.0564
#
# Epoch 00021: loss did not improve from 11.73025
# Epoch 22/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.6758 - acc: 0.0568
#
# Epoch 00022: loss improved from 11.73025 to 11.67579, saving model to galaxyLSTMmodel-22-11.6758.hdf5
# Epoch 23/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8484 - acc: 0.0580
#
# Epoch 00023: loss did not improve from 11.67579
# Epoch 24/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8870 - acc: 0.0586
#
# Epoch 00024: loss did not improve from 11.67579
# Epoch 25/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8005 - acc: 0.0574
#
# Epoch 00025: loss did not improve from 11.67579
# Epoch 26/200
# 10381/10381 [==============================] - 20s 2ms/step - loss: 11.8969 - acc: 0.0582
#
# Epoch 00026: loss did not improve from 11.67579
# Epoch 27/200
# 10381/10381 [==============================] - 20s 2ms/step - loss: 11.8392 - acc: 0.0552
#
# Epoch 00027: loss did not improve from 11.67579
# Epoch 28/200
# 10381/10381 [==============================] - 25s 2ms/step - loss: 11.7275 - acc: 0.0587
#
# Epoch 00028: loss did not improve from 11.67579
# Epoch 29/200
# 10381/10381 [==============================] - 19s 2ms/step - loss: 11.7129 - acc: 0.0566
#
# Epoch 00029: loss did not improve from 11.67579
# Epoch 30/200
# 10381/10381 [==============================] - 20s 2ms/step - loss: 11.6572 - acc: 0.0562
#
# Epoch 00030: loss improved from 11.67579 to 11.65721, saving model to galaxyLSTMmodel-30-11.6572.hdf5
# Epoch 31/200
# 10381/10381 [==============================] - 18s 2ms/step - loss: 11.8983 - acc: 0.0552
#
# Epoch 00031: loss did not improve from 11.65721
# Epoch 32/200
# 10381/10381 [==============================] - 23s 2ms/step - loss: 11.6680 - acc: 0.0554
#
# Epoch 00032: loss did not improve from 11.65721
# Epoch 33/200
# 10381/10381 [==============================] - 22s 2ms/step - loss: 12.0107 - acc: 0.0565
#
# Epoch 00033: loss did not improve from 11.65721
# Epoch 34/200
# 10381/10381 [==============================] - 20s 2ms/step - loss: 11.6372 - acc: 0.0566
#
# Epoch 00034: loss improved from 11.65721 to 11.63720, saving model to galaxyLSTMmodel-34-11.6372.hdf5
# Epoch 35/200
# 10381/10381 [==============================] - 23s 2ms/step - loss: 11.6145 - acc: 0.0603
#
# Epoch 00035: loss improved from 11.63720 to 11.61450, saving model to galaxyLSTMmodel-35-11.6145.hdf5
# Epoch 36/200
# 10381/10381 [==============================] - 24s 2ms/step - loss: 11.9390 - acc: 0.0591
#
# Epoch 00036: loss did not improve from 11.61450
# Epoch 37/200
# 10381/10381 [==============================] - 28s 3ms/step - loss: 11.6945 - acc: 0.0583
#
# Epoch 00037: loss did not improve from 11.61450
# Epoch 38/200
# 10381/10381 [==============================] - 25s 2ms/step - loss: 11.6895 - acc: 0.0576
#
# Epoch 00038: loss did not improve from 11.61450
# Epoch 39/200
# 10381/10381 [==============================] - 23s 2ms/step - loss: 11.7759 - acc: 0.0544
#
# Epoch 00039: loss did not improve from 11.61450
# Epoch 40/200
# 10381/10381 [==============================] - 27s 3ms/step - loss: 11.7814 - acc: 0.0554
#
# Epoch 00040: loss did not improve from 11.61450
# Epoch 41/200
# 10381/10381 [==============================] - 23s 2ms/step - loss: 11.8414 - acc: 0.0539
#
# Epoch 00041: loss did not improve from 11.61450
# Epoch 42/200
# 10381/10381 [==============================] - 22s 2ms/step - loss: 11.8670 - acc: 0.0574
#
# Epoch 00042: loss did not improve from 11.61450
# Epoch 43/200
# 10381/10381 [==============================] - 26s 2ms/step - loss: 11.6905 - acc: 0.0584
#
# Epoch 00043: loss did not improve from 11.61450
# Epoch 44/200
# 10381/10381 [==============================] - 23s 2ms/step - loss: 11.8927 - acc: 0.0583
#
# Epoch 00044: loss did not improve from 11.61450
# Epoch 45/200
# 10381/10381 [==============================] - 23s 2ms/step - loss: 11.7323 - acc: 0.0587
#
# Epoch 00045: loss did not improve from 11.61450
# Epoch 46/200
# 10381/10381 [==============================] - 28s 3ms/step - loss: 11.9253 - acc: 0.0596
#
# Epoch 00046: loss did not improve from 11.61450
# Epoch 47/200
# 10381/10381 [==============================] - 29s 3ms/step - loss: 11.7659 - acc: 0.0592
#
# Epoch 00047: loss did not improve from 11.61450
# Epoch 48/200
# 10381/10381 [==============================] - 25s 2ms/step - loss: 11.7136 - acc: 0.0571
#
# Epoch 00048: loss did not improve from 11.61450
# Epoch 49/200
# 10381/10381 [==============================] - 24s 2ms/step - loss: 11.5067 - acc: 0.0600
#
# Epoch 00049: loss improved from 11.61450 to 11.50671, saving model to galaxyLSTMmodel-49-11.5067.hdf5
# Epoch 50/200
# 10381/10381 [==============================] - 32s 3ms/step - loss: 11.6119 - acc: 0.0563
#
# Epoch 00050: loss did not improve from 11.50671
# Epoch 51/200
# 10381/10381 [==============================] - 25s 2ms/step - loss: 11.7889 - acc: 0.0564
#
# Epoch 00051: loss did not improve from 11.50671
# Epoch 52/200
# 10381/10381 [==============================] - 34s 3ms/step - loss: 11.7287 - acc: 0.0565
#
# Epoch 00052: loss did not improve from 11.50671
# Epoch 53/200
# 10381/10381 [==============================] - 38s 4ms/step - loss: 11.7367 - acc: 0.0591
#
# Epoch 00053: loss did not improve from 11.50671
# Epoch 54/200
# 10381/10381 [==============================] - 30s 3ms/step - loss: 11.8922 - acc: 0.0568
#
# Epoch 00054: loss did not improve from 11.50671
# Epoch 55/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.8574 - acc: 0.0547
#
# Epoch 00055: loss did not improve from 11.50671
# Epoch 56/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.7315 - acc: 0.0585
#
# Epoch 00056: loss did not improve from 11.50671
# Epoch 57/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.9262 - acc: 0.0551
#
# Epoch 00057: loss did not improve from 11.50671
# Epoch 58/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.6981 - acc: 0.0573
#
# Epoch 00058: loss did not improve from 11.50671
# Epoch 59/200
# 10381/10381 [==============================] - 20s 2ms/step - loss: 11.9333 - acc: 0.0617
#
# Epoch 00059: loss did not improve from 11.50671
# Epoch 60/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8740 - acc: 0.0562
#
# Epoch 00060: loss did not improve from 11.50671
# Epoch 61/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.6942 - acc: 0.0587
#
# Epoch 00061: loss did not improve from 11.50671
# Epoch 62/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.8645 - acc: 0.0626
#
# Epoch 00062: loss did not improve from 11.50671
# Epoch 63/200
# 10381/10381 [==============================] - 12s 1ms/step - loss: 11.8278 - acc: 0.0555
#
# Epoch 00063: loss did not improve from 11.50671
# Epoch 64/200
# 10381/10381 [==============================] - 12s 1ms/step - loss: 11.6916 - acc: 0.0568
#
# Epoch 00064: loss did not improve from 11.50671
# Epoch 65/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.9760 - acc: 0.0538
#
# Epoch 00065: loss did not improve from 11.50671
# Epoch 66/200
# 10381/10381 [==============================] - 12s 1ms/step - loss: 11.7282 - acc: 0.0620
#
# Epoch 00066: loss did not improve from 11.50671
# Epoch 67/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 11.7348 - acc: 0.0607
#
# Epoch 00067: loss did not improve from 11.50671
# Epoch 68/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 11.8312 - acc: 0.0548
#
# Epoch 00068: loss did not improve from 11.50671
# Epoch 69/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8718 - acc: 0.0591
#
# Epoch 00069: loss did not improve from 11.50671
# Epoch 70/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 11.8325 - acc: 0.0559
#
# Epoch 00070: loss did not improve from 11.50671
# Epoch 71/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8122 - acc: 0.0573
#
# Epoch 00071: loss did not improve from 11.50671
# Epoch 72/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8230 - acc: 0.0538
#
# Epoch 00072: loss did not improve from 11.50671
# Epoch 73/200
# 10381/10381 [==============================] - 21s 2ms/step - loss: 11.6321 - acc: 0.0594
#
# Epoch 00073: loss did not improve from 11.50671
# Epoch 74/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8426 - acc: 0.0591
#
# Epoch 00074: loss did not improve from 11.50671
# Epoch 75/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.9073 - acc: 0.0551
#
# Epoch 00075: loss did not improve from 11.50671
# Epoch 76/200
# 10381/10381 [==============================] - 16s 1ms/step - loss: 11.5950 - acc: 0.0587
#
# Epoch 00076: loss did not improve from 11.50671
# Epoch 77/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.9693 - acc: 0.0535
#
# Epoch 00077: loss did not improve from 11.50671
# Epoch 78/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.6214 - acc: 0.0576
#
# Epoch 00078: loss did not improve from 11.50671
# Epoch 79/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.7594 - acc: 0.0558
#
# Epoch 00079: loss did not improve from 11.50671
# Epoch 80/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.9274 - acc: 0.0528
#
# Epoch 00080: loss did not improve from 11.50671
# Epoch 81/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8618 - acc: 0.0591
#
# Epoch 00081: loss did not improve from 11.50671
# Epoch 82/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8168 - acc: 0.0571
#
# Epoch 00082: loss did not improve from 11.50671
# Epoch 83/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.7134 - acc: 0.0538
#
# Epoch 00083: loss did not improve from 11.50671
# Epoch 84/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8011 - acc: 0.0551
#
# Epoch 00084: loss did not improve from 11.50671
# Epoch 85/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.9091 - acc: 0.0591
#
# Epoch 00085: loss did not improve from 11.50671
# Epoch 86/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.7443 - acc: 0.0563
#
# Epoch 00086: loss did not improve from 11.50671
# Epoch 87/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8864 - acc: 0.0590
#
# Epoch 00087: loss did not improve from 11.50671
# Epoch 88/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.9062 - acc: 0.0566
#
# Epoch 00088: loss did not improve from 11.50671
# Epoch 89/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.7481 - acc: 0.0583
#
# Epoch 00089: loss did not improve from 11.50671
# Epoch 90/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.9655 - acc: 0.0567
#
# Epoch 00090: loss did not improve from 11.50671
# Epoch 91/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.6370 - acc: 0.0586
#
# Epoch 00091: loss did not improve from 11.50671
# Epoch 92/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8214 - acc: 0.0567
#
# Epoch 00092: loss did not improve from 11.50671
# Epoch 93/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.7786 - acc: 0.0549
#
# Epoch 00093: loss did not improve from 11.50671
# Epoch 94/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.7387 - acc: 0.0575
#
# Epoch 00094: loss did not improve from 11.50671
# Epoch 95/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.6376 - acc: 0.0595
#
# Epoch 00095: loss did not improve from 11.50671
# Epoch 96/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8415 - acc: 0.0585
#
# Epoch 00096: loss did not improve from 11.50671
# Epoch 97/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8004 - acc: 0.0583
#
# Epoch 00097: loss did not improve from 11.50671
# Epoch 98/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8050 - acc: 0.0550
#
# Epoch 00098: loss did not improve from 11.50671
# Epoch 99/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.7965 - acc: 0.0574
#
# Epoch 00099: loss did not improve from 11.50671
# Epoch 100/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.6945 - acc: 0.0585
#
# Epoch 00100: loss did not improve from 11.50671
# Epoch 101/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8145 - acc: 0.0575
#
# Epoch 00101: loss did not improve from 11.50671
# Epoch 102/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8505 - acc: 0.0580
#
# Epoch 00102: loss did not improve from 11.50671
# Epoch 103/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.8845 - acc: 0.0565
#
# Epoch 00103: loss did not improve from 11.50671
# Epoch 104/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.6783 - acc: 0.0576
#
# Epoch 00104: loss did not improve from 11.50671
# Epoch 105/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.7509 - acc: 0.0560
#
# Epoch 00105: loss did not improve from 11.50671
# Epoch 106/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8391 - acc: 0.0554
#
# Epoch 00106: loss did not improve from 11.50671
# Epoch 107/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.7467 - acc: 0.0581
#
# Epoch 00107: loss did not improve from 11.50671
# Epoch 108/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.9636 - acc: 0.0558
#
# Epoch 00108: loss did not improve from 11.50671
# Epoch 109/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8217 - acc: 0.0600
#
# Epoch 00109: loss did not improve from 11.50671
# Epoch 110/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.7333 - acc: 0.0564
#
# Epoch 00110: loss did not improve from 11.50671
# Epoch 111/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8104 - acc: 0.0605
#
# Epoch 00111: loss did not improve from 11.50671
# Epoch 112/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.7622 - acc: 0.0589
#
# Epoch 00112: loss did not improve from 11.50671
# Epoch 113/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.9345 - acc: 0.0564
#
# Epoch 00113: loss did not improve from 11.50671
# Epoch 114/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.9423 - acc: 0.0549
#
# Epoch 00114: loss did not improve from 11.50671
# Epoch 115/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8643 - acc: 0.0544
#
# Epoch 00115: loss did not improve from 11.50671
# Epoch 116/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8625 - acc: 0.0581
#
# Epoch 00116: loss did not improve from 11.50671
# Epoch 117/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.9109 - acc: 0.0617
#
# Epoch 00117: loss did not improve from 11.50671
# Epoch 118/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.6692 - acc: 0.0595
#
# Epoch 00118: loss did not improve from 11.50671
# Epoch 119/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.7241 - acc: 0.0608
#
# Epoch 00119: loss did not improve from 11.50671
# Epoch 120/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8298 - acc: 0.0581
#
# Epoch 00120: loss did not improve from 11.50671
# Epoch 121/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 12.0139 - acc: 0.0560
#
# Epoch 00121: loss did not improve from 11.50671
# Epoch 122/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.7681 - acc: 0.0572
#
# Epoch 00122: loss did not improve from 11.50671
# Epoch 123/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8003 - acc: 0.0557
#
# Epoch 00123: loss did not improve from 11.50671
# Epoch 124/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8863 - acc: 0.0587
#
# Epoch 00124: loss did not improve from 11.50671
# Epoch 125/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.7324 - acc: 0.0562
#
# Epoch 00125: loss did not improve from 11.50671
# Epoch 126/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8972 - acc: 0.0583
#
# Epoch 00126: loss did not improve from 11.50671
# Epoch 127/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.7577 - acc: 0.0573
#
# Epoch 00127: loss did not improve from 11.50671
# Epoch 128/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.7035 - acc: 0.0582
#
# Epoch 00128: loss did not improve from 11.50671
# Epoch 129/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.7195 - acc: 0.0549
#
# Epoch 00129: loss did not improve from 11.50671
# Epoch 130/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.9685 - acc: 0.0563
#
# Epoch 00130: loss did not improve from 11.50671
# Epoch 131/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.9054 - acc: 0.0565
#
# Epoch 00131: loss did not improve from 11.50671
# Epoch 132/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8753 - acc: 0.0573
#
# Epoch 00132: loss did not improve from 11.50671
# Epoch 133/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8065 - acc: 0.0591
#
# Epoch 00133: loss did not improve from 11.50671
# Epoch 134/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.7953 - acc: 0.0601
#
# Epoch 00134: loss did not improve from 11.50671
# Epoch 135/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8438 - acc: 0.0555
#
# Epoch 00135: loss did not improve from 11.50671
# Epoch 136/200
# 10381/10381 [==============================] - 18s 2ms/step - loss: 11.8695 - acc: 0.0557
#
# Epoch 00136: loss did not improve from 11.50671
# Epoch 137/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.7696 - acc: 0.0556
#
# Epoch 00137: loss did not improve from 11.50671
# Epoch 138/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.9961 - acc: 0.0556
#
# Epoch 00138: loss did not improve from 11.50671
# Epoch 139/200
# 10381/10381 [==============================] - 18s 2ms/step - loss: 11.8187 - acc: 0.0568
#
# Epoch 00139: loss did not improve from 11.50671
# Epoch 140/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8026 - acc: 0.0556
#
# Epoch 00140: loss did not improve from 11.50671
# Epoch 141/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8183 - acc: 0.0610
#
# Epoch 00141: loss did not improve from 11.50671
# Epoch 142/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8703 - acc: 0.0602
#
# Epoch 00142: loss did not improve from 11.50671
# Epoch 143/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.9379 - acc: 0.0575
#
# Epoch 00143: loss did not improve from 11.50671
# Epoch 144/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.6933 - acc: 0.0586
#
# Epoch 00144: loss did not improve from 11.50671
# Epoch 145/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 11.8097 - acc: 0.0596
#
# Epoch 00145: loss did not improve from 11.50671
# Epoch 146/200
# 10381/10381 [==============================] - 15s 1ms/step - loss: 12.0032 - acc: 0.0603
#
# Epoch 00146: loss did not improve from 11.50671
# Epoch 147/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8918 - acc: 0.0540
#
# Epoch 00147: loss did not improve from 11.50671
# Epoch 148/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.7588 - acc: 0.0582
#
# Epoch 00148: loss did not improve from 11.50671
# Epoch 149/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8913 - acc: 0.0552
#
# Epoch 00149: loss did not improve from 11.50671
# Epoch 150/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.7699 - acc: 0.0566
#
# Epoch 00150: loss did not improve from 11.50671
# Epoch 151/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8417 - acc: 0.0602
#
# Epoch 00151: loss did not improve from 11.50671
# Epoch 152/200
# 10381/10381 [==============================] - 18s 2ms/step - loss: 11.9034 - acc: 0.0540
#
# Epoch 00152: loss did not improve from 11.50671
# Epoch 153/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.7826 - acc: 0.0554
#
# Epoch 00153: loss did not improve from 11.50671
# Epoch 154/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8460 - acc: 0.0555
#
# Epoch 00154: loss did not improve from 11.50671
# Epoch 155/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8154 - acc: 0.0573
#
# Epoch 00155: loss did not improve from 11.50671
# Epoch 156/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.9163 - acc: 0.0534
#
# Epoch 00156: loss did not improve from 11.50671
# Epoch 157/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8642 - acc: 0.0585
#
# Epoch 00157: loss did not improve from 11.50671
# Epoch 158/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.8719 - acc: 0.0557
#
# Epoch 00158: loss did not improve from 11.50671
# Epoch 159/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.7162 - acc: 0.0593
#
# Epoch 00159: loss did not improve from 11.50671
# Epoch 160/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 12.0778 - acc: 0.0593
#
# Epoch 00160: loss did not improve from 11.50671
# Epoch 161/200
# 10381/10381 [==============================] - 18s 2ms/step - loss: 11.8799 - acc: 0.0564
#
# Epoch 00161: loss did not improve from 11.50671
# Epoch 162/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.9184 - acc: 0.0565
#
# Epoch 00162: loss did not improve from 11.50671
# Epoch 163/200
# 10381/10381 [==============================] - 18s 2ms/step - loss: 11.9171 - acc: 0.0548
#
# Epoch 00163: loss did not improve from 11.50671
# Epoch 164/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8496 - acc: 0.0548
#
# Epoch 00164: loss did not improve from 11.50671
# Epoch 165/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.9720 - acc: 0.0558
#
# Epoch 00165: loss did not improve from 11.50671
# Epoch 166/200
# 10381/10381 [==============================] - 22s 2ms/step - loss: 11.8377 - acc: 0.0583
#
# Epoch 00166: loss did not improve from 11.50671
# Epoch 167/200
# 10381/10381 [==============================] - 18s 2ms/step - loss: 11.9406 - acc: 0.0572
#
# Epoch 00167: loss did not improve from 11.50671
# Epoch 168/200
# 10381/10381 [==============================] - 18s 2ms/step - loss: 11.9254 - acc: 0.0591
#
# Epoch 00168: loss did not improve from 11.50671
# Epoch 169/200
# 10381/10381 [==============================] - 19s 2ms/step - loss: 11.8384 - acc: 0.0556
#
# Epoch 00169: loss did not improve from 11.50671
# Epoch 170/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.7671 - acc: 0.0557
#
# Epoch 00170: loss did not improve from 11.50671
# Epoch 171/200
# 10381/10381 [==============================] - 19s 2ms/step - loss: 11.9078 - acc: 0.0598
#
# Epoch 00171: loss did not improve from 11.50671
# Epoch 172/200
# 10381/10381 [==============================] - 19s 2ms/step - loss: 11.8227 - acc: 0.0643
#
# Epoch 00172: loss did not improve from 11.50671
# Epoch 173/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.9272 - acc: 0.0582
#
# Epoch 00173: loss did not improve from 11.50671
# Epoch 174/200
# 10381/10381 [==============================] - 22s 2ms/step - loss: 12.0408 - acc: 0.0591
#
# Epoch 00174: loss did not improve from 11.50671
# Epoch 175/200
# 10381/10381 [==============================] - 18s 2ms/step - loss: 11.6000 - acc: 0.0576
#
# Epoch 00175: loss did not improve from 11.50671
# Epoch 176/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8560 - acc: 0.0589
#
# Epoch 00176: loss did not improve from 11.50671
# Epoch 177/200
# 10381/10381 [==============================] - 19s 2ms/step - loss: 11.8672 - acc: 0.0632
#
# Epoch 00177: loss did not improve from 11.50671
# Epoch 178/200
# 10381/10381 [==============================] - 19s 2ms/step - loss: 11.8666 - acc: 0.0576
#
# Epoch 00178: loss did not improve from 11.50671
# Epoch 179/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.9655 - acc: 0.0594
#
# Epoch 00179: loss did not improve from 11.50671
# Epoch 180/200
# 10381/10381 [==============================] - 17s 2ms/step - loss: 11.7602 - acc: 0.0564
#
# Epoch 00180: loss did not improve from 11.50671
# Epoch 181/200
# 10381/10381 [==============================] - 19s 2ms/step - loss: 11.8841 - acc: 0.0567
#
# Epoch 00181: loss did not improve from 11.50671
# Epoch 182/200
# 10381/10381 [==============================] - 21s 2ms/step - loss: 12.0485 - acc: 0.0553
#
# Epoch 00182: loss did not improve from 11.50671
# Epoch 183/200
# 10381/10381 [==============================] - 18s 2ms/step - loss: 11.7110 - acc: 0.0530
#
# Epoch 00183: loss did not improve from 11.50671
# Epoch 184/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.7501 - acc: 0.0517
#
# Epoch 00184: loss did not improve from 11.50671
# Epoch 185/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 11.9491 - acc: 0.0578
#
# Epoch 00185: loss did not improve from 11.50671
# Epoch 186/200
# 10381/10381 [==============================] - 14s 1ms/step - loss: 11.9271 - acc: 0.0582
#
# Epoch 00186: loss did not improve from 11.50671
# Epoch 187/200
# 10381/10381 [==============================] - 13s 1ms/step - loss: 11.7224 - acc: 0.0585
#
# Epoch 00187: loss did not improve from 11.50671
# Epoch 188/200
# 10381/10381 [==============================] - 22s 2ms/step - loss: 11.8774 - acc: 0.0599
#
# Epoch 00188: loss did not improve from 11.50671
# Epoch 189/200
# 10381/10381 [==============================] - 26s 3ms/step - loss: 11.8346 - acc: 0.0566
#
# Epoch 00189: loss did not improve from 11.50671
# Epoch 190/200
# 10381/10381 [==============================] - 22s 2ms/step - loss: 12.0060 - acc: 0.0564
#
# Epoch 00190: loss did not improve from 11.50671
# Epoch 191/200
# 10381/10381 [==============================] - 16s 2ms/step - loss: 11.8603 - acc: 0.0558
#
# Epoch 00191: loss did not improve from 11.50671
# Epoch 192/200
# 10381/10381 [==============================] - 23s 2ms/step - loss: 12.0116 - acc: 0.0556
#
# Epoch 00192: loss did not improve from 11.50671
# Epoch 193/200
# 10381/10381 [==============================] - 25s 2ms/step - loss: 11.9643 - acc: 0.0591
#
# Epoch 00193: loss did not improve from 11.50671
# Epoch 194/200
# 10381/10381 [==============================] - 21s 2ms/step - loss: 11.8238 - acc: 0.0534
#
# Epoch 00194: loss did not improve from 11.50671
# Epoch 195/200
# 10381/10381 [==============================] - 28s 3ms/step - loss: 11.9317 - acc: 0.0574
#
# Epoch 00195: loss did not improve from 11.50671
# Epoch 196/200
# 10381/10381 [==============================] - 28s 3ms/step - loss: 11.8901 - acc: 0.0559
#
# Epoch 00196: loss did not improve from 11.50671
# Epoch 197/200
# 10381/10381 [==============================] - 26s 3ms/step - loss: 11.9254 - acc: 0.0586
#
# Epoch 00197: loss did not improve from 11.50671
# Epoch 198/200
# 10381/10381 [==============================] - 26s 3ms/step - loss: 11.9042 - acc: 0.0591
#
# Epoch 00198: loss did not improve from 11.50671
# Epoch 199/200
# 10381/10381 [==============================] - 26s 2ms/step - loss: 11.8983 - acc: 0.0556
#
# Epoch 00199: loss did not improve from 11.50671
# Epoch 200/200
# 10381/10381 [==============================] - 27s 3ms/step - loss: 11.9005 - acc: 0.0569
#
# Epoch 00200: loss did not improve from 11.50671

# %%
# Imports for visualisations
from IPython.display import HTML as html_print
from IPython.display import display

# Get output from intermediate layer to visualize activation
attn_func = K.function(inputs = [ model.get_input_at(0), 		K.learning_phase()], outputs = [lstm.output]) 

# Function to visualize the LSTM cell learnings
def cellVisualize(ovalues, rlist, cell_no):
        print("\nCell Number:", cell_no, "\n")
        textColours = []
        for i in range(len(ovalues)):
                text = (rlist[i], getColor(ovalues[i][cell_no]))
                textColours.append(text)
        printColor(textColours)

# get color for a given value
def getColor(value):
        colors = ['#85c2e1', '#89c4e2', '#95cae5', '#99cce6', '#a1d0e8'
                '#b2d9ec', '#baddee', '#c2e1f0', '#eff7fb', '#f9e8e8',
                '#f9e8e8', '#f9d4d4', '#f9bdbd', '#f8a8a8', '#f68f8f',
                '#f47676', '#f45f5f', '#f34343', '#f33b3b', '#f42e2e']
        value = int((value * 100) / 5)
        return colors[value]

def sigmoid(x):
        z = 1/(1 + np.exp(-x))
        return z
    
# get html element
def cstr(s, color='black'):
	if s == ' ':
		return "<text style=color:#000;padding-left:10px;background-color:{}> </text>".format(color, s)
	else:
		return "<text style=color:#000;background-color:{}>{} </text>".format(color, s)
    
# print html
def printColor(t):
	display(html_print(''.join([cstr(ti, color=ci) for ti,ci in t])))

# Get Predictions given the input of random sequence
def get_predictions(data):
        start = np.random.randint(0, len(data)-1)
        pattern = data[start]
        resultList, outputValues = [], []
        print("\"" + ''.join([integerToCharacter[value] for value in pattern]) + "\"")

        for i in range(500):
                # Reshaping input array for predicting next character
                x = np.reshape(pattern, (1, len(pattern), 1))
                x = x / float(numOfVocab)

                # Predict the text for the given random input
                prediction = model.predict(x, verbose=0)

                # Get the LSTM Activations from the attention function
                output = attn_func([x])[0][0]
                output = sigmoid(output)
                outputValues.append(output)

                # Get the predicted character
                index = np.argmax(prediction)
                result = integerToCharacter[index]

                # Now the current character is predicted, prepare for the next character
                inSequence = [integerToCharacter[value] for value in pattern]
                pattern.append(index)
                pattern = pattern[1:len(pattern)]

                # Save generated characters in a list
                resultList.append(result)
        return outputValues, resultList

predictedOutput, ListResult = get_predictions(dataX)

#cellsToBeVisualized = [ give the cell numbers]
cellsToBeVisualized = [ 10, 163, 30]

for ncell in cellsToBeVisualized:
        cellVisualize(predictedOutput, ListResult, ncell)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-457f28a59ce1> in <module>
#       4
#       5 # Get output from intermediate layer to visualize activation
# ----> 6 attn_func = K.function(inputs = [ model.get_input_at(0),                K.learning_phase()], outputs = [lstm.output])
#       7
#       8 # Function to visualize the LSTM cell learnings
#
# NameError: name 'K' is not defined
